# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from category_encoders import TargetEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import KFold, cross_val_score
import optuna
from tqdm import tqdm
from joblib import parallel_backend

def create_features(df):
    df = df.copy()
    
    # Gestion des outliers par IQR
    numeric_cols = ['median_income', 'total_rooms', 'total_bedrooms', 'population', 'households']
    for col in numeric_cols:
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        iqr = q3 - q1
        df[col] = df[col].clip(q1 - 1.5*iqr, q3 + 1.5*iqr)
    
    # Transformations non-linéaires
    df['income_log'] = np.log1p(df['median_income'])
    df['rooms_log'] = np.log1p(df['total_rooms'])
    df['income_squared'] = df['median_income']**2
    
    # Ratios et densités
    df['rooms_per_household'] = df['total_rooms']/df['households']
    df['bedrooms_ratio'] = df['total_bedrooms']/df['total_rooms']
    df['population_density'] = df['population']/df['households']
    
    # Interactions économiques
    df['income_per_person'] = df['median_income']/df['population']
    df['rooms_per_income'] = df['total_rooms']/df['median_income']
    df['income_age_interaction'] = df['median_income'] * df['housing_median_age']
    
    # Métriques composites
    df['crowding_index'] = (df['population'] * df['housing_median_age'])/(df['total_rooms'] + 1)
    df['economic_density'] = (df['median_income'] * df['households'])/(df['total_rooms'] + 1)
    
    return df

# Load data
train_data = pd.read_csv('../ynov-data/train_housing_train.csv')
valid_data = pd.read_csv('../ynov-data/train_housing_valid.csv')

columns_to_drop = ['longitude', 'latitude', 'id', 'median_house_value']
X_train = create_features(train_data.drop(columns=columns_to_drop))
y_train = train_data['median_house_value']

X_valid = create_features(valid_data.drop(columns=columns_to_drop))
y_valid = valid_data['median_house_value']

# Preprocessing
numeric_features = X_train.select_dtypes(include=['float64', 'int64']).columns
categorical_features = X_train.select_dtypes(include=['object']).columns

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', RobustScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('encoder', TargetEncoder())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 200, 400, step=50),
        'max_depth': trial.suggest_int('max_depth', 10, 20),  # Réduit pour limiter overfitting
        'min_samples_split': trial.suggest_int('min_samples_split', 5, 15),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 3, 7),
        'max_features': trial.suggest_float('max_features', 0.5, 0.7),  # Plage plus restreinte
        'max_samples': trial.suggest_float('max_samples', 0.6, 0.8),
        'bootstrap': True,
        'n_jobs': -1
    }
    
    model = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', RandomForestRegressor(random_state=42, **params))
    ])
    
    with parallel_backend('threading', n_jobs=-1):
        cv_scores = cross_val_score(
            model, 
            X_train, 
            y_train,
            cv=KFold(n_splits=5, shuffle=True, random_state=42),
            scoring='neg_root_mean_squared_error',
            n_jobs=-1
        )
    
    return -np.mean(cv_scores)

# Moins de trials mais exploration plus large
n_trials = 20

# Create SQLite storage
storage_name = "sqlite:///./stats.sqlite3?timeout=10000&check_same_thread=False"
study_name = "random_forest_housing_optimization"

# Create study with modified storage settings
study = optuna.create_study(
    study_name=study_name,
    storage=storage_name,
    direction='minimize',
    sampler=optuna.samplers.TPESampler(multivariate=True, seed=42),
    load_if_exists=True
)

# Modify optimization to use less parallelism to avoid DB locks
with tqdm(total=n_trials, desc='Optimization Progress') as pbar:
    study.optimize(
        objective, 
        n_trials=n_trials,
        n_jobs=4,  # Reduced from -1 to avoid DB contention
        show_progress_bar=False,
        callbacks=[lambda study, trial: pbar.update(1)]
    )

print("\nMeilleurs paramètres:", study.best_params)
print("Meilleur score:", study.best_value)

# Final model with best parameters
final_model = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(random_state=42, **study.best_params))
])

final_model.fit(X_train, y_train)

# Metrics
train_predictions = final_model.predict(X_train)
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
train_r2 = r2_score(y_train, train_predictions)

print(f'\nTraining RMSE: {train_rmse:.2f}')
print(f'Training R²: {train_r2:.2f}')

valid_predictions = final_model.predict(X_valid)
valid_rmse = np.sqrt(mean_squared_error(y_valid, valid_predictions))
valid_r2 = r2_score(y_valid, valid_predictions)

print(f'Validation RMSE: {valid_rmse:.2f}')
print(f'Validation R²: {valid_r2:.2f}')

# Generate submission file
test_data = pd.read_csv('../ynov-data/test_housing.csv')
X_test = create_features(test_data.drop('id', axis=1))
test_predictions = final_model.predict(X_test)

submission = pd.DataFrame({
    'id': test_data['id'],
    'median_house_value': test_predictions
})
submission.to_csv('../ynov-data/submission.csv', index=False)
# Out:
# /home/zehelh/.cache/pypoetry/virtualenvs/ynov-bZ5hcnR3-py3.10/lib/python3.10/site-packages/optuna/_experimental.py:31: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2024-12-12 13:55:18,029] Using an existing study with name 'random_forest_housing_optimization' instead of creating a new one.
# Optimization Progress:   0%|                             | 0/20 [00:00<?, ?it/s][W 2024-12-12 13:55:18,458] The parameter 'max_depth' in trial#33 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:18,558] The parameter 'max_depth' in trial#34 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:18,616] The parameter 'min_samples_split' in trial#34 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:19,382] The parameter 'max_depth' in trial#35 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:19,834] The parameter 'max_samples' in trial#33 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:19,929] The parameter 'min_samples_split' in trial#35 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:20,096] The parameter 'max_depth' in trial#36 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:20,603] The parameter 'min_samples_leaf' in trial#35 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:21,684] The parameter 'min_samples_leaf' in trial#36 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:21,830] The parameter 'max_samples' in trial#35 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:22,303] The parameter 'max_features' in trial#36 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:22,922] The parameter 'max_samples' in trial#36 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:55:49,534] Trial 33 finished with value: 59246.61740435292 and parameters: {'n_estimators': 200, 'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.5, 'max_samples': 0.7756501862687577}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:   5%|█                    | 1/20 [00:31<09:58, 31.51s/it][I 2024-12-12 13:55:50,080] Trial 35 finished with value: 59188.93800457435 and parameters: {'n_estimators': 250, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 0.7, 'max_samples': 0.7567481531154348}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  10%|██                   | 2/20 [00:32<03:59, 13.29s/it][I 2024-12-12 13:55:50,084] Trial 34 finished with value: 59163.37725181684 and parameters: {'n_estimators': 400, 'max_depth': 19, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 0.5, 'max_samples': 0.8}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  15%|███▏                 | 3/20 [00:32<01:27,  5.13s/it][W 2024-12-12 13:55:50,099] The parameter 'n_estimators' in trial#37 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:50,168] The parameter 'max_depth' in trial#37 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:50,286] The parameter 'min_samples_split' in trial#37 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:50,354] The parameter 'min_samples_leaf' in trial#37 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:50,480] The parameter 'max_features' in trial#37 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:50,656] The parameter 'max_samples' in trial#37 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:55:50,663] Trial 36 finished with value: 59193.34740224708 and parameters: {'n_estimators': 400, 'max_depth': 19, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': 0.5510151091128993, 'max_samples': 0.7558989244566604}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  20%|████▏                | 4/20 [00:32<00:59,  3.72s/it][W 2024-12-12 13:55:50,734] The parameter 'n_estimators' in trial#38 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:50,894] The parameter 'max_depth' in trial#38 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:50,918] The parameter 'n_estimators' in trial#39 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:51,028] The parameter 'min_samples_split' in trial#38 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:51,276] The parameter 'max_depth' in trial#39 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:51,733] The parameter 'min_samples_leaf' in trial#38 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:51,862] The parameter 'n_estimators' in trial#40 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:52,349] The parameter 'min_samples_split' in trial#39 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:52,789] The parameter 'max_features' in trial#38 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:53,110] The parameter 'max_depth' in trial#40 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:53,324] The parameter 'min_samples_leaf' in trial#39 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:53,487] The parameter 'max_samples' in trial#38 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:53,940] The parameter 'min_samples_split' in trial#40 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:54,362] The parameter 'max_features' in trial#39 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:54,947] The parameter 'min_samples_leaf' in trial#40 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:55,942] The parameter 'max_samples' in trial#39 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:56,120] The parameter 'max_features' in trial#40 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:55:57,120] The parameter 'max_samples' in trial#40 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:56:20,523] Trial 37 finished with value: 59185.2357200377 and parameters: {'n_estimators': 300, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 0.5445348814868448, 'max_samples': 0.6354777813801884}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  25%|█████▎               | 5/20 [01:02<02:56, 11.74s/it][W 2024-12-12 13:56:21,096] The parameter 'n_estimators' in trial#41 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:21,273] The parameter 'max_depth' in trial#41 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:21,331] The parameter 'min_samples_split' in trial#41 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:21,390] The parameter 'min_samples_leaf' in trial#41 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:56:21,397] Trial 38 finished with value: 59114.2929951276 and parameters: {'n_estimators': 300, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 0.6463497639517536, 'max_samples': 0.6518177394760629}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  30%|██████▎              | 6/20 [01:03<01:57,  8.43s/it][I 2024-12-12 13:56:21,409] Trial 40 finished with value: 59145.38545051483 and parameters: {'n_estimators': 300, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 0.6388858272327251, 'max_samples': 0.6468700312865027}. Best is trial 25 with value: 58139.32794555723.
# [W 2024-12-12 13:56:21,466] The parameter 'max_features' in trial#41 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:56:21,472] Trial 39 finished with value: 59152.530581846 and parameters: {'n_estimators': 300, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 0.6466539461778052, 'max_samples': 0.6477238000444693}. Best is trial 25 with value: 58139.32794555723.
# [W 2024-12-12 13:56:21,533] The parameter 'max_samples' in trial#41 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:25,874] The parameter 'n_estimators' in trial#42 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:26,844] The parameter 'max_depth' in trial#42 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:26,982] The parameter 'n_estimators' in trial#44 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:27,300] The parameter 'min_samples_split' in trial#42 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:27,426] The parameter 'max_depth' in trial#44 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:27,438] The parameter 'n_estimators' in trial#43 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:27,520] The parameter 'min_samples_leaf' in trial#42 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:27,600] The parameter 'max_depth' in trial#43 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:27,659] The parameter 'min_samples_split' in trial#44 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:27,736] The parameter 'max_features' in trial#42 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:27,801] The parameter 'max_samples' in trial#42 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:27,911] The parameter 'min_samples_leaf' in trial#44 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:27,987] The parameter 'max_features' in trial#44 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:28,128] The parameter 'min_samples_split' in trial#43 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:28,304] The parameter 'max_samples' in trial#44 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:28,560] The parameter 'min_samples_leaf' in trial#43 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:29,330] The parameter 'max_features' in trial#43 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:56:30,231] Trial 41 finished with value: 59248.773213269924 and parameters: {'n_estimators': 250, 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 0.5495300894230712, 'max_samples': 0.6368266747257741}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  45%|█████████▍           | 9/20 [01:12<00:58,  5.36s/it][W 2024-12-12 13:56:30,568] The parameter 'max_samples' in trial#43 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:37,275] The parameter 'n_estimators' in trial#45 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:39,179] The parameter 'max_depth' in trial#45 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:40,513] The parameter 'min_samples_split' in trial#45 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:41,918] The parameter 'min_samples_leaf' in trial#45 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:43,372] The parameter 'max_features' in trial#45 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:45,130] The parameter 'max_samples' in trial#45 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:56:45,833] Trial 42 finished with value: 59206.037071506245 and parameters: {'n_estimators': 250, 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 0.5491487673916633, 'max_samples': 0.6320195693333579}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  50%|██████████          | 10/20 [01:27<01:14,  7.49s/it][I 2024-12-12 13:56:49,180] Trial 44 finished with value: 59163.58420100034 and parameters: {'n_estimators': 250, 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 0.5428782740397673, 'max_samples': 0.621646265947605}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  55%|███████████         | 11/20 [01:31<00:58,  6.54s/it][W 2024-12-12 13:56:52,450] The parameter 'n_estimators' in trial#46 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:54,259] The parameter 'max_depth' in trial#46 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:54,317] The parameter 'min_samples_split' in trial#46 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:54,376] The parameter 'min_samples_leaf' in trial#46 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:54,435] The parameter 'max_features' in trial#46 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:54,494] The parameter 'max_samples' in trial#46 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:55,149] The parameter 'n_estimators' in trial#47 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:56:55,363] The parameter 'max_depth' in trial#47 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:56:55,494] Trial 43 finished with value: 59152.88648697212 and parameters: {'n_estimators': 250, 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.5541634146138044, 'max_samples': 0.619816995492494}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  60%|████████████        | 12/20 [01:37<00:52,  6.51s/it][W 2024-12-12 13:56:56,271] The parameter 'min_samples_split' in trial#47 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:56:56,999] Trial 45 finished with value: 59146.251802343715 and parameters: {'n_estimators': 350, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 0.5215957507734644, 'max_samples': 0.6132989600238247}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  65%|█████████████       | 13/20 [01:39<00:36,  5.18s/it][W 2024-12-12 13:56:57,507] The parameter 'min_samples_leaf' in trial#47 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:01,397] The parameter 'max_features' in trial#47 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:03,063] The parameter 'max_samples' in trial#47 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:04,415] The parameter 'n_estimators' in trial#48 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:57:06,459] Trial 46 finished with value: 59186.09777276724 and parameters: {'n_estimators': 350, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 0.520448377044666, 'max_samples': 0.6112874042253494}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  70%|██████████████      | 14/20 [01:48<00:38,  6.34s/it][W 2024-12-12 13:57:06,474] The parameter 'max_depth' in trial#48 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:08,901] The parameter 'min_samples_split' in trial#48 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:09,125] The parameter 'n_estimators' in trial#49 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:11,005] The parameter 'max_depth' in trial#49 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:12,019] The parameter 'n_estimators' in trial#50 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:12,074] The parameter 'max_depth' in trial#50 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:12,133] The parameter 'min_samples_split' in trial#50 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:12,191] The parameter 'min_samples_leaf' in trial#48 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:12,250] The parameter 'min_samples_leaf' in trial#50 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:12,359] The parameter 'max_features' in trial#48 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:12,418] The parameter 'max_samples' in trial#48 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:12,477] The parameter 'max_features' in trial#50 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:12,536] The parameter 'max_samples' in trial#50 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:12,712] The parameter 'min_samples_split' in trial#49 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:57:12,936] Trial 47 finished with value: 59154.86549302278 and parameters: {'n_estimators': 350, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 0.5174410505471875, 'max_samples': 0.6079869060843722}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  75%|███████████████     | 15/20 [01:54<00:31,  6.36s/it][W 2024-12-12 13:57:13,039] The parameter 'min_samples_leaf' in trial#49 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:16,166] The parameter 'max_features' in trial#49 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:17,356] The parameter 'max_samples' in trial#49 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:23,720] The parameter 'n_estimators' in trial#51 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:24,907] The parameter 'max_depth' in trial#51 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:26,048] The parameter 'min_samples_split' in trial#51 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:27,084] The parameter 'min_samples_leaf' in trial#51 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:27,380] The parameter 'max_features' in trial#51 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:28,544] The parameter 'max_samples' in trial#51 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:57:41,309] Trial 48 finished with value: 59186.09777276724 and parameters: {'n_estimators': 350, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 0.5184752261022753, 'max_samples': 0.61128724229539}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  80%|████████████████    | 16/20 [02:23<00:50, 12.66s/it][I 2024-12-12 13:57:41,439] Trial 50 finished with value: 59144.48486615681 and parameters: {'n_estimators': 350, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 0.5141686304632724, 'max_samples': 0.609856158583623}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  85%|█████████████████   | 17/20 [02:23<00:27,  9.02s/it][W 2024-12-12 13:57:42,204] The parameter 'n_estimators' in trial#52 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:57:42,223] Trial 49 finished with value: 59144.4848661568 and parameters: {'n_estimators': 350, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 0.5168349822907894, 'max_samples': 0.6098831049559345}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  90%|██████████████████  | 18/20 [02:24<00:13,  6.61s/it][W 2024-12-12 13:57:42,353] The parameter 'max_depth' in trial#52 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:43,358] The parameter 'min_samples_split' in trial#52 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:43,417] The parameter 'min_samples_leaf' in trial#52 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:57:43,425] Trial 51 finished with value: 59282.76570337264 and parameters: {'n_estimators': 350, 'max_depth': 20, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': 0.5164172043118032, 'max_samples': 0.6100498868450497}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress:  95%|███████████████████ | 19/20 [02:25<00:05,  5.01s/it][W 2024-12-12 13:57:43,476] The parameter 'max_features' in trial#52 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2024-12-12 13:57:43,535] The parameter 'max_samples' in trial#52 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [I 2024-12-12 13:57:53,351] Trial 52 finished with value: 59190.712780566326 and parameters: {'n_estimators': 350, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 0.5922131551668721, 'max_samples': 0.7856688166540404}. Best is trial 25 with value: 58139.32794555723.
# Optimization Progress: 100%|████████████████████| 20/20 [02:35<00:00,  7.77s/it]
# Meilleurs paramètres: {'n_estimators': 300, 'max_depth': 30, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.6000000000000001, 'max_samples': 0.6, 'criterion': 'squared_error', 'ccp_alpha': 0.01}
# Meilleur score: 58139.32794555723
#
# Training RMSE: 42232.53
# Training R²: 0.87
# Validation RMSE: 60886.47
# Validation R²: 0.74
